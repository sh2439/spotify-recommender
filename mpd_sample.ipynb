# %% [markdown]
# ### Dependency

# %%
import sys
import os
import numpy as np
import pandas as pd
import json
import os.path as osp
from tqdm.auto import tqdm
from collections import defaultdict

# Minhash and jaccard
from sklearn.metrics import jaccard_score
from datasketch import MinHash, MinHashLSH

# %% [markdown]
# ### Load the dataset

# %%
data_dir = 'spotify_million_playlist_dataset/data'
file_names = os.listdir(data_dir)

file_dir = osp.join(data_dir, file_names[0])

f = open(file_dir) 

# Load json file
data = json.load(f) 
# check the number of playlists
print(len(data['playlists']))
# Out:
# 1000

# %% [markdown]
# ### Preprocessing the dataset

# %%
### helper function: convert dict to panda dataframe
def convert(data):
    """
    Convert the json file to a panda dataframe and a dict.
        
    Returns:
        df: dataframe with columns (playlist id, track name and ratings (all 1)).
        df_dict: python dict, key is the playlist id, values are a list of track names.
    """
    
    df = []
    df_dict = defaultdict(list)
    for idx, playlist in tqdm(enumerate(data['playlists'])):

        p_id = playlist['pid']

        tracks = playlist['tracks']

        for track in tracks:

            df.append([p_id, track['track_name'], 1])
            df_dict[p_id].append(track['track_name'])
            
            
    df = pd.DataFrame(df)
    df.columns = ['p_id', 'track_name', 'rating']
    
    return df, df_dict

# %%
df, df_dict = convert(data)

#preview df_dict
print('The tracks of playlist id 549000: \n',df_dict[549000])

# preview df
df
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# The tracks of playlist id 549000:
#  ['Boots of Spanish Leather', 'Mr. Tambourine Man', "Danny's Song", "A Hard Rain's A-Gonna Fall", "Blowin' In the Wind", 'John Wesley Harding', 'If You See Her, Say Hello', "Bob Dylan's 115th Dream", 'Love Minus Zero', 'Classy Girls', 'Girl from the North Country', "03' Bonnie & Clyde", 'Que Quieres De Mi', 'Wicked Games', 'Slow It Down', 'How Deep Is Your Love', 'Mi verdad - feat. Shakira', 'Moon River(Vocal Audrey Hepburn)', "I've Got The World On A String", 'A Little Less Conversation', "That's All Right", 'Piano Man', 'New York State of Mind', "(I Can't Help) Falling in Love With You", 'Happy Together', 'In My Dreams', 'Keep on Loving You - Remastered', "Somethin' Stupid", 'The Way You Look Tonight', 'Blue Moon - 1998 Digital Remaster', 'Hold You in My Arms', "Can't Fight This Feeling", 'Shooting Star', 'I Don\'t Want to Miss a Thing - From the Touchstone film, "Armageddon"', 'Then', 'Us Against the World', 'Love Your Love the Most', 'The Real Thing', 'Lay Lady Lay - Alternative Version', 'All My Loving - From "Across The Universe" Soundtrack', 'It Makes Me Ill', "Can't Help Falling In Love - Recorded Live at Daytrotter", 'Comfortable - EP Version', 'Love Me Harder', "This Ain't Goodbye", 'The Moon Song', 'Half of My Heart', 'Edge of Desire', 'Assassin', 'Your Body Is a Wonderland', 'Uptown Girl', 'Maybe I’m Amazed - Remastered 2011', 'Shotgun Rider', 'Vultures', 'Fire', 'Photograph', "She's Everything", 'Meet Virginia', 'Parachute', 'Drops of Jupiter', 'Sweet Baby James', 'Make You Feel My Love', 'You Make It Look So Easy', 'Wild Child (with Grace Potter)', 'Our House', "Free Fallin'", 'My Way', 'Born to Run', 'Wrecking Ball', "Ain't Even Done With The Night", 'Thunder Road', 'No Surrender', 'Jungleland', 'Like A Wrecking Ball', 'For You']
#          p_id                                         track_name  rating
# 0      549000                           Boots of Spanish Leather       1
# 1      549000                                 Mr. Tambourine Man       1
# 2      549000                                       Danny's Song       1
# 3      549000                         A Hard Rain's A-Gonna Fall       1
# 4      549000                                Blowin' In the Wind       1
# ...       ...                                                ...     ...
# 68684  549999     Fünf heitere Gesänge, Op.125: 1. "Die Meerfee"       1
# 68685  549999   L'incoronazione di Poppea / Act 3: "Pur ti miro"       1
# 68686  549999  Pergolesi: Stabat mater: VII. Eja Mater, fons ...       1
# 68687  549999           Sound the trumpet, beat the drum, Z. 335       1
# 68688  549999  Purcell: Ode for Queen Mary's Birthday (Come Y...       1
#
# [68689 rows x 3 columns]

# %%
### Convert the dataframe to utility matrix
U = pd.pivot_table(df, values='rating', index='p_id', columns='track_name')
U
# Out:
# track_name  "45"  "C" Is For Cookie - Introduction  \
# p_id
# 549000       NaN                               NaN
# 549001       NaN                               NaN
# 549002       NaN                               NaN
# 549003       NaN                               NaN
# 549004       NaN                               NaN
# ...          ...                               ...
# 549995       NaN                               NaN
# 549996       NaN                               NaN
# 549997       NaN                               NaN
# 549998       NaN                               NaN
# 549999       NaN                               NaN
#
# track_name  "If You Want a Burger..." (feat. Kiesha Red)  \
# p_id
# 549000                                               NaN
# 549001                                               NaN
# 549002                                               NaN
# 549003                                               NaN
# 549004                                               NaN
# ...                                                  ...
# 549995                                               NaN
# 549996                                               NaN
# 549997                                               NaN
# 549998                                               NaN
# 549999                                               NaN
#
# track_name  "O Mio Babbino Caro" (From Gianni Schicchi)  \
# p_id
# 549000                                              NaN
# 549001                                              NaN
# 549002                                              NaN
# 549003                                              NaN
# 549004                                              NaN
# ...                                                 ...
# 549995                                              NaN
# 549996                                              NaN
# 549997                                              NaN
# 549998                                              NaN
# 549999                                              NaN
#
# track_name  "The Take Over, The Breaks Over"  #9 Dream  \
# p_id
# 549000                                   NaN       NaN
# 549001                                   NaN       NaN
# 549002                                   NaN       NaN
# 549003                                   NaN       NaN
# 549004                                   NaN       NaN
# ...                                      ...       ...
# 549995                                   NaN       NaN
# 549996                                   NaN       NaN
# 549997                                   NaN       NaN
# 549998                                   NaN       NaN
# 549999                                   NaN       NaN
#
# track_name  #BDAY (feat. Chris Brown, Siya and Sage The Gemini)  \
# p_id
# 549000                                                    NaN
# 549001                                                    NaN
# 549002                                                    NaN
# 549003                                                    NaN
# 549004                                                    NaN
# ...                                                       ...
# 549995                                                    NaN
# 549996                                                    NaN
# 549997                                                    NaN
# 549998                                                    NaN
# 549999                                                    NaN
#
# track_name  #Beastmode (feat. Gametime Henderson-Vine)  #Beautiful  #Dubigal  \
# p_id
# 549000                                             NaN         NaN       NaN
# 549001                                             NaN         NaN       NaN
# 549002                                             NaN         NaN       NaN
# 549003                                             NaN         NaN       NaN
# 549004                                             NaN         NaN       NaN
# ...                                                ...         ...       ...
# 549995                                             NaN         NaN       NaN
# 549996                                             NaN         NaN       NaN
# 549997                                             NaN         NaN       NaN
# 549998                                             NaN         NaN       NaN
# 549999                                             NaN         NaN       NaN
#
# track_name  ...  아.미.고 Amigo (SHINee WORLD 1 Version)  아직도 난 (Still you)  \
# p_id        ...
# 549000      ...                                   NaN                NaN
# 549001      ...                                   NaN                NaN
# 549002      ...                                   NaN                NaN
# 549003      ...                                   NaN                NaN
# 549004      ...                                   NaN                NaN
# ...         ...                                   ...                ...
# 549995      ...                                   NaN                NaN
# 549996      ...                                   NaN                NaN
# 549997      ...                                   NaN                NaN
# 549998      ...                                   NaN                NaN
# 549999      ...                                   NaN                NaN
#
# track_name  양화대교 (Yanghwa Brdg)  으르렁 Growl  잔소리 (feat. Simon D)  좋아 She is  \
# p_id
# 549000                      NaN        NaN                  NaN        NaN
# 549001                      NaN        NaN                  NaN        NaN
# 549002                      NaN        NaN                  NaN        NaN
# 549003                      NaN        NaN                  NaN        NaN
# 549004                      NaN        NaN                  NaN        NaN
# ...                         ...        ...                  ...        ...
# 549995                      NaN        NaN                  NaN        NaN
# 549996                      NaN        NaN                  NaN        NaN
# 549997                      NaN        NaN                  NaN        NaN
# 549998                      NaN        NaN                  NaN        NaN
# 549999                      NaN        NaN                  NaN        NaN
#
# track_name  중독 Overdose  쿠데타 COUP D'ETAT  하이엔드걸 [High End Girl] (feat. Deez)  \
# p_id
# 549000              NaN              NaN                                 NaN
# 549001              NaN              NaN                                 NaN
# 549002              NaN              NaN                                 NaN
# 549003              NaN              NaN                                 NaN
# 549004              NaN              NaN                                 NaN
# ...                 ...              ...                                 ...
# 549995              NaN              NaN                                 NaN
# 549996              NaN              NaN                                 NaN
# 549997              NaN              NaN                                 NaN
# 549998              1.0              NaN                                 NaN
# 549999              NaN              NaN                                 NaN
#
# track_name  헤픈엔딩 Happen Ending
# p_id
# 549000                     NaN
# 549001                     NaN
# 549002                     NaN
# 549003                     NaN
# 549004                     NaN
# ...                        ...
# 549995                     NaN
# 549996                     NaN
# 549997                     NaN
# 549998                     NaN
# 549999                     NaN
#
# [1000 rows x 31009 columns]

# %% [markdown]
# ### Minhash and LSH

# %%
# Convert null values to 0
U[U.isna()] = 0

# %%
random_seed = 100
threshold = 0.06 # jaccard sim threshold
# Initialize the LSH
lsh = MinHashLSH(threshold = threshold, num_perm=128)
MH = {}
for idx, key in tqdm(enumerate(sorted(df_dict))):
    
    MH[key] = MinHash(seed = random_seed)
    for d in df_dict[key]:
        MH[key].update(d.encode('utf8'))
  
    lsh.insert(key, MH[key])
    
# find the neighbor of query playlist q
q = 549121
result = lsh.query(MH[q])
print('playlist {} neighbors: {}'.format(q, result))

print('----')
for i in result:
    if i != q:
    
        print('Actually jaccard similarity: ', jaccard_score(U.loc[q, :], U.loc[i, :]))
        print('Predicted Similarity:', MH[549121].jaccard(MH[i]) , '\n')
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# playlist 549121 neighbors: [549121, 549411, 549194, 549775, 549489]
# ----
# Actually jaccard similarity:  0.017241379310344827
# Predicted Similarity: 0.03125
#
# Actually jaccard similarity:  0.0625
# Predicted Similarity: 0.0859375
#
# Actually jaccard similarity:  0.022222222222222223
# Predicted Similarity: 0.03125
#
# Actually jaccard similarity:  0.015748031496062992
# Predicted Similarity: 0.015625
